# %%
from obspy import read, read_inventory

# %%
st=read('datasets/f/arg26_1653z0_19980101_0200.msd')
tr=st[0]
tr.plot();

# %%
inv = read_inventory("RESP.XX.NS458..BNZ.CMG5T.DC_200.4G_10V")
pre_filt = [70, 80, 250, 260]
tr.remove_response(inventory=inv, pre_filt=pre_filt, output="ACC", plot=True) #DISP,VEL,ACC
# Out:
# .1653..HHZ | 1998-01-01T02:45:10.000000Z - 1998-01-01T02:46:21.995000Z | 200.0 Hz, 14400 samples

# %%
import numpy as np

# %%
tr.data
# Out:
# array([-0.52326891, -0.826386  ,  5.16513507, ...,  1.87432705,
#         1.34878055, -0.37367997])

# %%
t=np.linspace(0,tr.stats.npts/tr.stats.sampling_rate,tr.stats.npts)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t,tr.data)

# %%
# ¿Porque sucede?
# Cada miembro con una traza
# Calculo de Ml con Peak Amplitude y radio
